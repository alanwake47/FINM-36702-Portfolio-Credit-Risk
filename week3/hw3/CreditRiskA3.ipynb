# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Question 1
#
# Let 𝑦 = 𝑙𝑔𝑑[𝑑𝑟], <br>
# then 𝑑𝑟 = 𝑦^2, <br><br> and we have:<br>
# 𝑝𝑑𝑓_𝑙𝑔𝑑[𝑙𝑔𝑑] = 𝑝𝑑𝑓_𝑑𝑟[𝑑𝑟] 𝑑(𝑑𝑟)/𝑑(𝑙𝑔𝑑) = 𝑝𝑑𝑓_𝑑𝑟[𝑦^2] 2𝑦
# <br><br>
# Substituting the expression for 𝑝𝑑𝑓_𝑑𝑟[𝑑𝑟], we get:
# 𝑝𝑑𝑓_𝑙𝑔𝑑[𝑙𝑔𝑑] = (2 - 2𝑦^2)2𝑦 = 4𝑦 - 4𝑦^3

# %%
def default_rate_pdf(dr):
    return 2 - 2 * dr

def lgd_pdf(lgd):
    return (4*lgd)-(4*lgd**3)

# %%
x = np.linspace(0, 1, 100)
plt.plot(x, default_rate_pdf(x), label='Default Rate')
plt.plot(np.sqrt(x), lgd_pdf(np.sqrt(x)), label='LGD')

plt.xlabel('Variable')
plt.ylabel('Probability Density Function')
plt.legend()

plt.show()

# %% [markdown]
# # Question 2

# %%
x = np.linspace(0, 1, 100)
plt.plot(x, default_rate_pdf(x), label='Default Rate')
plt.plot(np.sqrt(x), lgd_pdf(np.sqrt(x)), label='LGD')

plt.xlabel('Variable')
plt.ylabel('Probability Density Function')
plt.ylim((0,3))
plt.legend()

plt.show()
